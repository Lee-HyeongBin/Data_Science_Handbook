# %% [markdown]
# # Matplotlib 맞춤변경하기 : 설정과 스타일시트

# %% [markdown]
# ## 직접 플롯 변경하기

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('classic')

# %%
x = np.random.randn(1000)
plt.hist(x)
# Out:
# (array([  5.,  19.,  70., 172., 214., 236., 182.,  70.,  26.,   6.]),
#  array([-3.24660823, -2.60827304, -1.96993785, -1.33160266, -0.69326747,
#         -0.05493228,  0.58340292,  1.22173811,  1.8600733 ,  2.49840849,
#          3.13674368]),
#  <a list of 10 Patch objects>)

# %%
# 회색 배경 사용
ax = plt.axes(facecolor = '#E6E6E6')
ax.set_axisbelow(True)

# 그리드 선을 하얀 실선으로 그림
plt.grid(color = 'w', linestyle = 'solid')

# 축 선(spine) 숨김
for spine in ax.spines.values():
    spine.set_visible(False)
    
# 위쪽, 오른쪽 눈금 감김
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()

# 눈금과 레이블 색을 밝게 변경
ax.tick_params(colors = 'gray', direction = 'out')
for tick in ax.get_xticklabels():
    tick.set_color('gray')
for tick in ax.get_yticklabels():
    tick.set_color('gray')
    
# 히스토그램 면과 테두리 색 조절
ax.hist(x, edgecolor = '#E6E6E6', color = '#EE6666')
# Out:
# (array([  5.,  19.,  70., 172., 214., 236., 182.,  70.,  26.,   6.]),
#  array([-3.24660823, -2.60827304, -1.96993785, -1.33160266, -0.69326747,
#         -0.05493228,  0.58340292,  1.22173811,  1.8600733 ,  2.49840849,
#          3.13674368]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## 기본값 변경하기 : rcParams

# %%
IPython_default = plt.rcParams.copy()

# %%
from matplotlib import cycler
colors = cycler('color', ['#EE6666', '#3388BB', '#9988DD', 'EECC55', '88BB44', 'FFBBBB'])
plt.rc('axes', facecolor = '#E6E6E6', edgecolor = 'none', axisbelow = True, grid = True, prop_cycle = colors)
plt.rc('grid', color = 'w', linestyle = 'solid')
plt.rc('xtick', direction = 'out', color = 'gray')
plt.rc('ytick', direction = 'out', color = 'gray')
plt.rc('patch', edgecolor = '#E6E6E6')
plt.rc('lines', linewidth = 2)

# %%
plt.hist(x)
# Out:
# (array([  5.,  19.,  70., 172., 214., 236., 182.,  70.,  26.,   6.]),
#  array([-3.24660823, -2.60827304, -1.96993785, -1.33160266, -0.69326747,
#         -0.05493228,  0.58340292,  1.22173811,  1.8600733 ,  2.49840849,
#          3.13674368]),
#  <a list of 10 Patch objects>)

# %%
for i in range(4):
    plt.plot(np.random.rand(10))

# %% [markdown]
# ## 스타일시트

# %%
plt.style.available[:5]
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background']

# %%
# # 기본 스타일시트 교체
# plt.style.use('스타일 이름')

# # 일시적으로 설정하는 스타일 컨텍스트 관리자
# with plt.style.context('스타일 이름'):
#     make_a_plot()

# %%
def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize = (15, 5))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
    ax[1].legend(['a', 'b', 'c'], loc = 'lower left')

# %%
plt.rcParams.update(IPython_default)
# Out:
# C:\Anaconda\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The datapath rcparam was deprecated in Matplotlib 3.2.1 and will be removed two minor releases later.
#   self[key] = other[key]
# C:\Anaconda\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# C:\Anaconda\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   self[key] = other[key]
# C:\Anaconda\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# C:\Anaconda\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]

# %%
hist_and_lines()

# %% [markdown]
# ### FiveThirtyEight 스타일

# %%
with plt.style.context('fivethirtyeight'):
    hist_and_lines()

# %% [markdown]
# ### ggplot

# %%
with plt.style.context('ggplot'):
    hist_and_lines()

# %% [markdown]
# ### Bayesian Methods and Hackers 스타일

# %%
with plt.style.context('bmh'):
    hist_and_lines()

# %% [markdown]
# ### Dark background 스타일

# %%
with plt.style.context('dark_background'):
    hist_and_lines()

# %% [markdown]
# ### Grayscale 스타일

# %%
with plt.style.context('grayscale'):
    hist_and_lines()

# %% [markdown]
# ### Seaborn 스타일

# %%
with plt.style.context('seaborn'):
    hist_and_lines()
