# %% [markdown]
# # 간단한 산점도

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('classic')
import numpy as np

# %% [markdown]
# ## plt.plot을 이용한 산점도

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color = 'black')

# %%
rng = np.random.RandomState(0)

for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker, label = "marker = '{0}'".format(marker))
    plt.legend(numpoints = 1)
    plt.xlim(0, 1.8)

# %%
plt.plot(x, y, '-ok') # 선(-), 원(o), 검정색(k)

# %%
plt.plot(x, y, '-p', color = 'gray', markersize = 15, linewidth = 4, markerfacecolor = 'white', markeredgecolor = 'gray', markeredgewidth = 2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# ## plt.scatter를 이용한 산점도

# %%
plt.scatter(x, y, marker = 'o')

# %% [markdown]
# * plt.scatter와 plt.plot의 차이점 : scatter의 경우, 각 점의 속성(크기, 표면 색상, 테두리 색상 등)을 개별적으로 제어하거나 데이터에 매핑할 수 있는 산점도를 만드는데 사용할 수 있다는 것이다.

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.figure(figsize = (10, 7))
plt.scatter(x, y, c = colors, s = sizes, alpha = 0.3, cmap = 'viridis')
plt.colorbar()

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha = 0.2, s = 100 * features[3], c = iris.target, cmap = 'viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# ## plot과 scatter의 차이 : 효율성 측면에서 유의할 점

# %% [markdown]
# * 데이터가 큰 경우에는 plt.plot(점이 서로 복제)을 사용하는 것이 plt.scatter(개별적 점 구성)를 사용하는 것보다 낫다.
